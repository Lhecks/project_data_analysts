# %% [markdown]
# ##### Quarter Job's Trend
# In this project, we are going to plot the number of pe term and also to the jo title
# Each term will have two bar chart the first will be for the number of jobs and the second will be for the top 3 job title

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('csv/new_dataset.csv')
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_posted_month'] = df.job_posted_date.dt.strftime('%b')
df
# Out:
#          Unnamed: 0   job_id  company_id job_title_short  \
# 0                 0        0           0    Data Analyst
# 1                 1        0           0    Data Analyst
# 2                 2        0           0    Data Analyst
# 3                 3        0           0    Data Analyst
# 4                 4        0           0    Data Analyst
# ...             ...      ...         ...             ...
# 3669599     3669599  1452207         154   Data Engineer
# 3669600     3669600  1452207         154   Data Engineer
# 3669601     3669601  1452207         154   Data Engineer
# 3669602     3669602  1452207         154   Data Engineer
# 3669603     3669603  1452207         154   Data Engineer
#
#                                                  job_title  \
# 0                                   Marketing Data Analyst
# 1                                   Marketing Data Analyst
# 2                                   Marketing Data Analyst
# 3                                   Marketing Data Analyst
# 4                                   Marketing Data Analyst
# ...                                                    ...
# 3669599  Principal Associate, Data Engineer (Remote-Eli...
# 3669600  Principal Associate, Data Engineer (Remote-Eli...
# 3669601  Principal Associate, Data Engineer (Remote-Eli...
# 3669602  Principal Associate, Data Engineer (Remote-Eli...
# 3669603  Principal Associate, Data Engineer (Remote-Eli...
#
#                                 job_location              job_via  \
# 0                                   Anywhere         via LinkedIn
# 1                                   Anywhere         via LinkedIn
# 2                                   Anywhere         via LinkedIn
# 3                                   Anywhere         via LinkedIn
# 4                                   Anywhere         via LinkedIn
# ...                                      ...                  ...
# 3669599  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 3669600  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 3669601  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 3669602  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 3669603  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
#
#         job_schedule_type  job_work_from_home search_location  \
# 0               Full-time                True          Serbia
# 1               Full-time                True          Serbia
# 2               Full-time                True          Serbia
# 3               Full-time                True          Serbia
# 4               Full-time                True          Serbia
# ...                   ...                 ...             ...
# 3669599   Pekerjaan tetap               False           Sudan
# 3669600   Pekerjaan tetap               False           Sudan
# 3669601   Pekerjaan tetap               False           Sudan
# 3669602   Pekerjaan tetap               False           Sudan
# 3669603   Pekerjaan tetap               False           Sudan
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-09-25 17:46:06                  False                 False
# 1       2023-09-25 17:46:06                  False                 False
# 2       2023-09-25 17:46:06                  False                 False
# 3       2023-09-25 17:46:06                  False                 False
# 4       2023-09-25 17:46:06                  False                 False
# ...                     ...                    ...                   ...
# 3669599 2023-03-12 06:32:15                  False                 False
# 3669600 2023-03-12 06:32:15                  False                 False
# 3669601 2023-03-12 06:32:15                  False                 False
# 3669602 2023-03-12 06:32:15                  False                 False
# 3669603 2023-03-12 06:32:15                  False                 False
#
#         job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0            Serbia         NaN              NaN              NaN
# 1            Serbia         NaN              NaN              NaN
# 2            Serbia         NaN              NaN              NaN
# 3            Serbia         NaN              NaN              NaN
# 4            Serbia         NaN              NaN              NaN
# ...             ...         ...              ...              ...
# 3669599       Sudan         NaN              NaN              NaN
# 3669600       Sudan         NaN              NaN              NaN
# 3669601       Sudan         NaN              NaN              NaN
# 3669602       Sudan         NaN              NaN              NaN
# 3669603       Sudan         NaN              NaN              NaN
#
#         job_posted_month      skills           type
# 0                    Sep         sql    programming
# 1                    Sep      python    programming
# 2                    Sep       excel  analyst_tools
# 3                    Sep     tableau  analyst_tools
# 4                    Sep    power bi  analyst_tools
# ...                  ...         ...            ...
# 3669599              Mar       spark      libraries
# 3669600              Mar      hadoop      libraries
# 3669601              Mar       kafka      libraries
# 3669602              Mar  kubernetes          other
# 3669603              Mar      docker          other
#
# [3669604 rows x 20 columns]

# %%
df_months = df['job_posted_month'].unique()
# df_months
{months : months for months in df_months}
months_dict = {months: df[df['job_posted_month'] == months] for months in df_months}
months_dict['Dec']
# Out:
#          Unnamed: 0   job_id  company_id   job_title_short  \
# 101             101      276          20  Business Analyst
# 102             102      276          20  Business Analyst
# 404             404     1427          77    Data Scientist
# 468             468     1675          90    Data Scientist
# 469             469     1675          90    Data Scientist
# ...             ...      ...         ...               ...
# 3669116     3669116   467142        1171  Business Analyst
# 3669117     3669117   467142        1171  Business Analyst
# 3669118     3669118   467142        1171  Business Analyst
# 3669119     3669119   467142        1171  Business Analyst
# 3669377     3669377  1632427      384082    Data Scientist
#
#                                                  job_title  \
# 101                                   Marketing Analyst/in
# 102                                   Marketing Analyst/in
# 404      Data Scientist & AI: Bootcamp and Project Work...
# 468                                         Data Scientist
# 469                                         Data Scientist
# ...                                                    ...
# 3669116                Data / Business Analyst (Ref 55053)
# 3669117                Data / Business Analyst (Ref 55053)
# 3669118                Data / Business Analyst (Ref 55053)
# 3669119                Data / Business Analyst (Ref 55053)
# 3669377                               Lead Data Consultant
#
#                      job_location               job_via  \
# 101               Munich, Germany             via BeBee
# 102               Munich, Germany             via BeBee
# 404                 Paris, France             via Moyyn
# 468      Pune, Maharashtra, India       via BeBee India
# 469      Pune, Maharashtra, India       via BeBee India
# ...                           ...                   ...
# 3669116                 Singapore  via Jobs Trabajo.org
# 3669117                 Singapore  via Jobs Trabajo.org
# 3669118                 Singapore  via Jobs Trabajo.org
# 3669119                 Singapore  via Jobs Trabajo.org
# 3669377                   Austria  via Jobs Trabajo.org
#
#                 job_schedule_type  job_work_from_home search_location  \
# 101                     Full-time               False         Germany
# 102                     Full-time               False         Germany
# 404                     Part-time               False          France
# 468                     Full-time               False           India
# 469                     Full-time               False           India
# ...                           ...                 ...             ...
# 3669116  Full-time and Contractor               False       Singapore
# 3669117  Full-time and Contractor               False       Singapore
# 3669118  Full-time and Contractor               False       Singapore
# 3669119  Full-time and Contractor               False       Singapore
# 3669377                 Full-time               False         Austria
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 101     2023-12-04 17:19:43                   True                 False
# 102     2023-12-04 17:19:43                   True                 False
# 404     2023-12-06 17:14:25                  False                 False
# 468     2023-12-23 17:09:13                  False                 False
# 469     2023-12-23 17:09:13                  False                 False
# ...                     ...                    ...                   ...
# 3669116 2023-12-01 06:28:16                  False                 False
# 3669117 2023-12-01 06:28:16                  False                 False
# 3669118 2023-12-01 06:28:16                  False                 False
# 3669119 2023-12-01 06:28:16                  False                 False
# 3669377 2023-12-09 06:21:31                   True                 False
#
#         job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 101         Germany         NaN              NaN              NaN
# 102         Germany         NaN              NaN              NaN
# 404          France         NaN              NaN              NaN
# 468           India         NaN              NaN              NaN
# 469           India         NaN              NaN              NaN
# ...             ...         ...              ...              ...
# 3669116   Singapore         NaN              NaN              NaN
# 3669117   Singapore         NaN              NaN              NaN
# 3669118   Singapore         NaN              NaN              NaN
# 3669119   Singapore         NaN              NaN              NaN
# 3669377     Austria         NaN              NaN              NaN
#
#         job_posted_month    skills           type
# 101                  Dec       sql    programming
# 102                  Dec  bigquery          cloud
# 404                  Dec    python    programming
# 468                  Dec    python    programming
# 469                  Dec     scala    programming
# ...                  ...       ...            ...
# 3669116              Dec   tableau  analyst_tools
# 3669117              Dec     visio  analyst_tools
# 3669118              Dec     excel  analyst_tools
# 3669119              Dec      jira          async
# 3669377              Dec    github          other
#
# [254748 rows x 20 columns]

# %%
conc_q1_dt = pd.concat([months_dict['Jan'], months_dict['Feb'], months_dict['Mar']], ignore_index=True)
conc_q1_dt['job_posted_month'].value_counts().plot(kind='bar')
plt.xlabel('Number of job Q1')
plt.xticks(rotation=0)
plt.title('Number of Jobs in Q1')
plt.ylim(0, 500000)
plt.show()

# %%
# Let's get first the top 3 job titles for Q1
top_job_q1 = conc_q1_dt['job_title_short'].value_counts().head(3)
top_job_list_q1 = top_job_q1.index.to_list()

# Filtering the DataFrame so that to get the top job titles
filtered_df_q1 = conc_q1_dt[conc_q1_dt['job_title_short'].isin(top_job_list_q1)].copy()

# Let's define the order of the months of the first Quater Q1
month_order_q1 = ['Jan', 'Feb', 'Mar']

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_df_q1['job_posted_month'] = pd.Categorical(filtered_df_q1['job_posted_month'], categories=month_order_q1, ordered=True)

grouped_data = filtered_df_q1.groupby(['job_posted_month', 'job_title_short'], observed=False).size().unstack(fill_value=0)

# Plot the grouped data
grouped_data.plot(kind='bar', stacked=False)
plt.xlabel('Q1')
plt.ylabel('Number of Jobs')
plt.title('Top 3 Job Titles per Month in Q1')
plt.xticks(rotation=0)
plt.legend(title='Job Title')
plt.ylim(0, 150000)
plt.show()

# %%
top_skills = conc_q1_dt['skills'].value_counts().head(3)
top_skills_list_q1 = top_skills.index.to_list()
top_skills_list_q1
# Out:
# ['sql', 'python', 'aws']

# %%
# Filtering the DataFrame so that to get the top job titles
filtered_skills_q1 = conc_q1_dt[conc_q1_dt['skills'].isin(top_skills_list_q1)].copy()

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_skills_q1['job_posted_month'] = pd.Categorical(filtered_skills_q1['job_posted_month'], categories=month_order_q1, ordered=True)

grouped_data = filtered_skills_q1.groupby(['job_posted_month', 'skills'], observed=False).size().unstack(fill_value=0)

# Plot the grouped data
grouped_data.plot(kind='bar', stacked=False)
plt.xlabel('Q1')
plt.ylabel('Number of Skills')
plt.title('Top 3 SKILLS for the First Term Q1')
plt.xticks(rotation=0)
plt.legend(title='SKILLs')
plt.ylim(0, 50000)
plt.show()

# %%
# Let's define the order of the months of the first Quater Q2
month_order_q2 = ['Apr', 'May', 'Jun']

# Concatenate the data for Q2
conc_q2_dt = pd.concat([months_dict['Apr'], months_dict['May'], months_dict['Jun']], ignore_index=True)

# Convert the 'job_posted_month' column to a categorical type with the specified order
conc_q2_dt['job_posted_month'] = pd.Categorical(conc_q2_dt['job_posted_month'], categories=month_order_q2, ordered=True)

# Count the occurrences of each month and plot them
month_counts = conc_q2_dt['job_posted_month'].value_counts().sort_index()

# Plot the data
month_counts.plot(kind='bar')
plt.xticks(rotation=0)
plt.xlabel('Month')
plt.ylabel('Number of Jobs')
plt.title('Number of Jobs in Q2')
plt.ylim(0, 350000)
plt.show()

# %%
# Concatenate the data for Q2
conc_q2_dt = pd.concat([months_dict['Apr'], months_dict['May'], months_dict['Jun']], ignore_index=True)

# Define the order of the months
month_order_q2 = ['Apr', 'May', 'Jun']

# Get the top 3 job titles for Q2
top_job_q2 = conc_q2_dt['job_title_short'].value_counts().head(3)
top_job_list_q2 = top_job_q2.index.to_list()

# Filter the DataFrame for the top job titles
filtered_df_q2 = conc_q2_dt[conc_q2_dt['job_title_short'].isin(top_job_list_q2)].copy()

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_df_q2.loc[:, 'job_posted_month'] = pd.Categorical(filtered_df_q2['job_posted_month'], categories=month_order_q2, ordered=True)

# Group the data by month and job title, and count the occurrences
grouped_data = filtered_df_q2.groupby(['job_posted_month', 'job_title_short'], observed=False).size().unstack(fill_value=0)

# Plot the grouped data
grouped_data.plot(kind='bar', stacked=False)
plt.xlabel('Q2')
plt.ylabel('Number of Jobs')
plt.title('Top 3 Job Titles per Month in Q2')
plt.xticks(rotation=0)
plt.legend(title='Job Title')
plt.ylim(0, 120000)
plt.show()

# %%
top_skills_2 = conc_q2_dt['skills'].value_counts().head(3)
top_skills_list_q2 = top_skills_2.index.to_list()
top_skills_list_q2
# Out:
# ['sql', 'python', 'aws']

# %%
# Filtering the DataFrame so that to get the top job titles
filtered_skills_q2 = conc_q2_dt[conc_q2_dt['skills'].isin(top_skills_list_q2)].copy()

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_skills_q2['job_posted_month'] = pd.Categorical(filtered_skills_q2['job_posted_month'], categories=month_order_q2, ordered=True)

grouped_data_skills_2 = filtered_skills_q2.groupby(['job_posted_month', 'skills'], observed=False).size().unstack(fill_value=0)

# Plot the grouped data
grouped_data_skills_2.plot(kind='bar', stacked=False)
plt.xlabel('Q2')
plt.ylabel('Number of Skills')
plt.title('Top 3 SKILLS for the First Term Q2')
plt.xticks(rotation=0)
plt.legend(title='SKILLs')
plt.ylim(0, 40000)
plt.show()

# %%
# Let's define the order of the months of the first Quater Q1
month_order_q3 = ['Jul', 'Aug', 'Sep']

# Concatenate the data for Q2
conc_q3_dt = pd.concat([months_dict['Jul'], months_dict['Aug'], months_dict['Sep']], ignore_index=True)

# Convert the 'job_posted_month' column to a categorical type with the specified order
conc_q3_dt['job_posted_month'] = pd.Categorical(conc_q3_dt['job_posted_month'], categories=month_order_q3, ordered=True)

# Count the occurrences of each month and plot them
month_counts = conc_q3_dt['job_posted_month'].value_counts().sort_index()

# Plot the data
month_counts.plot(kind='bar')
plt.xticks(rotation=0)
plt.xlabel('Q3')
plt.ylabel('Number of Jobs')
plt.title('Number of Jobs in Q3')
plt.ylim(0, 400000)
plt.show()

# %%
# Let's get first the top 3 job titles for Q1
top_job_q3 = conc_q3_dt['job_title_short'].value_counts().head(3)
top_job_list_q3 = top_job_q3.index.to_list()

# Filtering the DataFrame so that to get the top job titles
filtered_df_q3 = conc_q3_dt[conc_q3_dt['job_title_short'].isin(top_job_list_q3)].copy()

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_df_q3['job_posted_month'] = pd.Categorical(filtered_df_q3['job_posted_month'], categories=month_order_q3, ordered=True)

grouped_data = filtered_df_q3.groupby(['job_posted_month', 'job_title_short'], observed=False).size().unstack(fill_value=0)

# Plot the grouped data
grouped_data.plot(kind='bar', stacked=False)
plt.xlabel('Q3')
plt.ylabel('Number of Jobs')
plt.title('Top 3 Job Titles per Month in Q3')
plt.xticks(rotation=0)
plt.legend(title='Job Title')
plt.ylim(0, 130000)
plt.show()

# %%
top_skills_3 = conc_q3_dt['skills'].value_counts().head(3)
top_skills_list_q3 = top_skills_3.index.to_list()
top_skills_list_q3
# Out:
# ['sql', 'python', 'aws']

# %%
# Filtering the DataFrame so that to get the top job titles
filtered_skills_q3 = conc_q3_dt[conc_q3_dt['skills'].isin(top_skills_list_q3)].copy()

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_skills_q3['job_posted_month'] = pd.Categorical(filtered_skills_q3['job_posted_month'], categories=month_order_q3, ordered=True)

grouped_data_skills_3 = filtered_skills_q3.groupby(['job_posted_month', 'skills'], observed=False).size().unstack(fill_value=0)

# Plot the grouped data
grouped_data_skills_3.plot(kind='bar', stacked=False)
plt.xlabel('Q3')
plt.ylabel('Number of Skills')
plt.title('Top 3 SKILLS for the First Term Q3')
plt.xticks(rotation=0)
plt.legend(title='SKILLs')
plt.ylim(0, 40000)
plt.show()

# %%
conc_q4_dt = pd.concat([months_dict['Oct'], months_dict['Nov'], months_dict['Dec']], ignore_index=True)
conc_q4_dt['job_posted_month'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.xlabel('Number of job Q4')
plt.ylim(0, 350000)
plt.show()

# %%
top_job = conc_q4_dt['job_title_short'].value_counts().head(3)
top_job = top_job.index.to_list()
month_order_q4 = ['Oct', 'Nov', 'Dec']
# top_job_list = top_job.index.to_list
filtered_df = conc_q4_dt[conc_q4_dt['job_title_short'].isin(top_job)].copy()

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_df['job_posted_month'] = pd.Categorical(filtered_df['job_posted_month'], categories=month_order_q4, ordered=True)

job_counts = filtered_df['job_title_short'].value_counts()
job_counts
grouped_data = filtered_df.groupby(['job_posted_month', 'job_title_short'], observed=False).size().unstack(fill_value=0)
# Plot the grouped data
grouped_data.plot(kind='bar', stacked=False)
plt.xlabel('Q4')
plt.ylabel('Number of Jobs')
plt.title('Top 3 Job Titles per Month in Q4')
plt.xticks(rotation=0)
plt.legend(title='Job Title')
plt.ylim(0, 120000)
plt.show()

# %%
top_skills_4 = conc_q3_dt['skills'].value_counts().head(3)
top_skills_list_q4 = top_skills_4.index.to_list()
top_skills_list_q4
# Out:
# ['sql', 'python', 'aws']

# %%
# Filtering the DataFrame so that to get the top job titles
filtered_skills_q4 = conc_q4_dt[conc_q4_dt['skills'].isin(top_skills_list_q4)].copy()

# Convert the 'job_posted_month' column to a categorical type with the specified order
filtered_skills_q4['job_posted_month'] = pd.Categorical(filtered_skills_q4['job_posted_month'], categories=month_order_q4, ordered=True)

grouped_data_skills_4 = filtered_skills_q4.groupby(['job_posted_month', 'skills'], observed=False).size().unstack(fill_value=0)

# Plot the grouped data
grouped_data_skills_4.plot(kind='bar', stacked=False)
plt.xlabel('Q4')
plt.ylabel('Number of Skills')
plt.title('Top 3 SKILLS for the First Term Q4')
plt.xticks(rotation=0)
plt.legend(title='SKILLs')
plt.ylim(0, 38000)
plt.show()
